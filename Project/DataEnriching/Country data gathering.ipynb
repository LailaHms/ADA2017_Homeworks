# %%
import pandas as pd
import numpy as np
import os
import requests
from bs4 import BeautifulSoup
import collections

# %% [markdown]
# ## Dataset 1: https://github.com/mledoze/countries

# %%
def get_language(df):
    """Takes the dataframe and, from the original column dict_of_languages, returns a dictionary where items are like 
       {country: list_of_language_names}"""
    languages = dict()
    for country, language_dict in zip(df.name.values, df.dict_of_languages.values):
        languages.update({country: list(language_dict.values())})
    
    return languages

            
def get_language_codes(df):
    """Takes the dataframe and, from the original column dict_of_languages, returns a dictionary where items are like 
       {country: list_of_language_codes}"""
    
    language_codes = dict()
    for country, language_dict in zip(df.name.values, df.dict_of_languages.values):
        if len(language_dict.keys()) > 0:
            language_codes.update({country: list(language_dict.keys())})
        else:
            language_codes.update({country: ['unknown']})
    
    return language_codes

def get_country_name_native(df):
    """Takes the dataframe and, from the original column dict_of_names, returns a dictionary where items are like 
       {country: list_of_native_country_names}. 
       The dict_of_names column conains the name of the country in various ways. This function only takes the common
       name of the country in the native language (i.e. we could also take the official name in the native language)"""
    
    native_names_dict = dict()
    for country, country_name_dict in zip(df.name, df.dict_of_names.values):
        native_country_names = []
        for native_lang in country_name_dict['native']:
            native_country_names.append(country_name_dict['native'][native_lang]['common'])
        native_names_dict.update({country: native_country_names})
    
    return native_names_dict
            

def add_columns(df):
    """Adds the following columns to the dataframe: name, name_native, languages and language_codes"""
    
    # Adding name & name_native columns
    df['name'] = [name['common'] for name in df.dict_of_names.values]
    country_native_names = get_country_name_native(df)
    df['name_native'] = list(country_native_names.values())
    
    # Getting the dictionaries needed to add the language columns
    languages = get_language(df)
    language_codes = get_language_codes(df)
    
    # Adding languages & language codes columns
    df['languages'] = list(languages.values())
    df['language_codes'] = list(language_codes.values())

    return df

# %%
# Read csv and renaming columns
countries = pd.read_json('countries.json')
countries.rename(columns={'name': 'dict_of_names', 'languages': 'dict_of_languages'}, inplace=True)

# Adding columns
countries = add_columns(countries)
# Select useful columns & renaming them
cols = ['area', 'cca2', 'cca3', 'ccn3', 'borders', 'name', 'language_codes', 'latlng', 'languages', 'name_native']
countries = countries[cols]
countries.rename(columns={'cca2': 'ISO2', 'cca3': 'ISO3', 'ccn3': 'ISO_num'}, inplace=True)

countries.head()
# Out:
#         area ISO2 ISO3 ISO_num                         borders           name  \
# 0      180.0   AW  ABW     533                              []          Aruba
# 1   652230.0   AF  AFG     004  [IRN, PAK, TKM, UZB, TJK, CHN]    Afghanistan
# 2  1246700.0   AO  AGO     024            [COG, COD, ZMB, NAM]         Angola
# 3       91.0   AI  AIA     660                              []       Anguilla
# 4     1580.0   AX  ALA     248                              []  Åland Islands
#
#     language_codes                 latlng                languages  \
# 0       [nld, pap]   [12.5, -69.96666666]      [Dutch, Papiamento]
# 1  [prs, pus, tuk]               [33, 65]  [Dari, Pashto, Turkmen]
# 2            [por]          [-12.5, 18.5]             [Portuguese]
# 3            [eng]  [18.25, -63.16666666]                [English]
# 4            [swe]      [60.116667, 19.9]                [Swedish]
#
#                           name_native
# 0                      [Aruba, Aruba]
# 1  [افغانستان, افغانستان, Owganystan]
# 2                            [Angola]
# 3                          [Anguilla]
# 4                             [Åland]

# %% [markdown]
# ## Dataset 2 : http://www.thearda.com/Archive/Files/Downloads/WRDNATL_DL2.asp
#
# The file contains all religions as columns, both totals and percentages. We only consider that a country has a certain religion if that religion has more than a treshold of 10% of adherents out of all the population. For that, we are only interested in the columns with percentages, which have 'PCT' in the name.
#
# More cleaning of the columns will be done after merging.

# %%
# Reading excel and selecting most recent data
pop_rel_df = pd.read_excel('World Religion Dataset - National Religion Dataset.xlsx')
pop_rel_df = pop_rel_df.loc[pop_rel_df['YEAR'] == '2010']

# Selecing useful columns
cols = ['ISO3', 'COUNTRY', 'POP', 'DUALREL'] + \
        [col for col in pop_rel_df.columns if 'PCT' in col]
pop_rel_df = pop_rel_df[cols]

# Renaming and reseting index
pop_rel_df.rename(columns={'NUMISO': 'ISO_num'}, inplace=True)
pop_rel_df.reset_index(drop=True, inplace=True)

pop_rel_df.head()
# Out:
#   ISO3                   COUNTRY          POP  DUALREL  CHPRTPCT  CHCATPCT  \
# 0  USA  United States of America  312,750,000        0  0.382900    0.2507
# 1  CAN                    Canada   34,500,000        0  0.229800    0.4202
# 2  BHS                   Bahamas      313,312        0  0.676000    0.1400
# 3  CUB                      Cuba   11,241,161        1  0.048899    0.6000
# 4  HTI                     Haiti    9,760,832        1  0.100000    0.7200
#
#    CHORTPCT  CHANGPCT  CHOTHPCT  CHGENPCT   ...    SHGENPCT  BAGENPCT  \
# 0  0.022499  0.015499  0.073800    0.7454   ...      0.0005    0.0015
# 1  0.022799  0.078899  0.014399    0.7661   ...      0.0000    0.0005
# 2  0.000000  0.150000  0.000000    0.9660   ...      0.0000    0.0000
# 3  0.000000  0.000000  0.009999    0.6589   ...      0.0000    0.0000
# 4  0.000000  0.000000  0.000000    0.8200   ...      0.0000    0.0009
#
#    TAGENPCT  JAGENPCT  COGENPCT  SYGENPCT  ANGENPCT  NORELPCT  OTGENPCT  \
# 0  0.000000  0.000300  0.000300  0.002599  0.005699  0.190000    0.0025
# 1  0.000099  0.000099  0.000099  0.000800  0.002100  0.164300    0.0010
# 2  0.000300  0.000000  0.000000  0.000000  0.003200  0.028999    0.0005
# 3  0.000000  0.000000  0.000000  0.500000  0.000000  0.131500    0.0000
# 4  0.000000  0.000000  0.000000  0.450000  0.000000  0.100000    0.0000
#
#    SUMPCT
# 0  0.9975
# 1  0.9990
# 2  0.9995
# 3  1.2935
# 4  1.3711
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Dataset 3
# Total: https://data.worldbank.org/indicator/NY.GDP.MKTP.CD
#
# Per capita: https://data.worldbank.org/indicator/NY.GDP.PCAP.CD
#
# We start by reading the two files into two different datagrames and then we merge them.

# %%
gdp_total = pd.read_csv('gdp_total.csv', skiprows=3)[['Country Name', 'Country Code', '2016']]
gdp_total.rename(columns={'2016': '2016_gdp_total', 'Country Code': 'ISO3'}, inplace=True)

# %%
gdp_capita = pd.read_csv('gdp_per_capita.csv', skiprows=4)[['Country Name', 'Country Code', '2016']]
gdp_capita.rename(columns={'2016': '2016_gdp_capita', 'Country Code': 'ISO3'}, inplace=True)

# %%
gdp_df = pd.merge(gdp_total, gdp_capita, on=['ISO3', 'Country Name'])
gdp_df.head()
# Out:
#   Country Name ISO3  2016_gdp_total  2016_gdp_capita
# 0        Aruba  ABW             NaN              NaN
# 1  Afghanistan  AFG    1.946902e+10       561.778746
# 2       Angola  AGO    8.963316e+10      3110.808183
# 3      Albania  ALB    1.192689e+10      4146.896250
# 4      Andorra  AND             NaN              NaN

# %% [markdown]
# ## Dataset 4 : https://github.com/opendatajson/factbook.json
#
# In this case we didn't have all the data in one file so the reading required more work. We created an empty dataframe and we run through all the folders and all the files inside them and appended the data to the dataframe, ignoring the index.
#
# The dataset contains GEC code for the country names, so we will have to use another source to make the mapping of the GEC codes with the ISO codes.

# %%
# Names of the folders
region_folders = ['africa', 'australia-oceania', 'central-america-n-caribbean', 'central-asia', 'east-n-southeast-asia',
          'europe', 'middle-east', 'north-america', 'south-america', 'south-asia']

# We use a temporaty df to load the data for a particular country and we append it to the main GEC_gov_type_df
GEC_gov_type_df = pd.DataFrame()
for region in region_folders:
    for country_file in os.listdir(r'factbook.json/' + region):
        df = pd.read_json(r'factbook.json/' + region + '/' + country_file)
        try:
            gov_type = df.loc['Government type', 'Government']['text']
        except:
            gov_type = 'unknown'
        
        GEC_gov_type_df = GEC_gov_type_df.append({'GEC_code': country_file[:2], 'gov_type': gov_type}, ignore_index=True)
    
GEC_gov_type_df.head()
# Out:
#   GEC_code                gov_type
# 0       ag   presidential republic
# 1       ao   presidential republic
# 2       bc  parliamentary republic
# 3       bn   presidential republic
# 4       by   presidential republic

# %% [markdown]
# As said, we need ISO codes instead of GEC codes so we scrape them from http://www.statoids.com/wab.html

# %%
r = requests.get('http://www.statoids.com/wab.html')
soup = BeautifulSoup(r.text, 'html.parser')

GEC_codes_df = pd.DataFrame()
for row in soup.find('table').find_all('tr')[1:-1]:
    col = row.find_all('td')
    GEC_codes_df = GEC_codes_df.append({'ISO2': col[1].text, 'ISO3': col[2].text, 'ISO_num': col[3].text, \
                                        'GEC_code': col[5].text.lower()}, ignore_index=True)

GEC_codes_df.head()
# Out:
#   GEC_code ISO2 ISO3 ISO_num
# 0       af   AF  AFG     004
# 1            AX  ALA     248
# 2       al   AL  ALB     008
# 3       ag   DZ  DZA     012
# 4       aq   AS  ASM     016

# %%
# Finally we merge on GEC codes
gov_type_df = pd.merge(GEC_gov_type_df, GEC_codes_df, on='GEC_code', how='outer')
gov_type_df.fillna('unknown', inplace=True)
gov_type_df.head()
# Out:
#   GEC_code                gov_type ISO2 ISO3 ISO_num
# 0       ag   presidential republic   DZ  DZA     012
# 1       ao   presidential republic   AO  AGO     024
# 2       bc  parliamentary republic   BW  BWA     072
# 3       bn   presidential republic   BJ  BEN     204
# 4       by   presidential republic   BI  BDI     108

# %% [markdown]
# ### Generating pickle files

# %%
countries.to_pickle('countries_df.pickle')
pop_rel_df.to_pickle('pop_rel_df.pickle')
gdp_df.to_pickle('gdp_df.pickle')
gov_type_df.to_pickle('gov_type_df.pickle')

# %% [markdown]
# # Merging in one dataframe

# %%
# First, we drop the columns of each dataframe that we don't want to use
pop_rel_df.drop('COUNTRY', axis=1, inplace=True)
gdp_df.drop('Country Name', axis=1, inplace=True)#
gov_type_df.drop(['ISO2', 'GEC_code'], axis=1, inplace=True)

# %%
# We merge all the dataframes on IS0 Alpha-3 (ISO3) code, one by one.
dataframes = [countries, pop_rel_df, gdp_df, gov_type_df]
data = countries.copy()
for df in dataframes[1:]:
    data = pd.merge(data, df, on='ISO3', how='outer')

# Convert country names to string & select all rows where we actually have the country name
data.name = data.name.apply(str)
data = data.loc[~(data.name == 'nan')]
data.set_index('name', inplace=True)
data.head()
# Out:
#                     area ISO2 ISO3 ISO_num_x                         borders  \
# name
# Aruba              180.0   AW  ABW       533                              []
# Afghanistan     652230.0   AF  AFG       004  [IRN, PAK, TKM, UZB, TJK, CHN]
# Angola         1246700.0   AO  AGO       024            [COG, COD, ZMB, NAM]
# Anguilla            91.0   AI  AIA       660                              []
# Åland Islands     1580.0   AX  ALA       248                              []
#
#                 language_codes                 latlng  \
# name
# Aruba               [nld, pap]   [12.5, -69.96666666]
# Afghanistan    [prs, pus, tuk]               [33, 65]
# Angola                   [por]          [-12.5, 18.5]
# Anguilla                 [eng]  [18.25, -63.16666666]
# Åland Islands            [swe]      [60.116667, 19.9]
#
#                              languages                         name_native  \
# name
# Aruba              [Dutch, Papiamento]                      [Aruba, Aruba]
# Afghanistan    [Dari, Pashto, Turkmen]  [افغانستان, افغانستان, Owganystan]
# Angola                    [Portuguese]                            [Angola]
# Anguilla                     [English]                          [Anguilla]
# Åland Islands                [Swedish]                             [Åland]
#
#                       POP    ...      COGENPCT  SYGENPCT  ANGENPCT  NORELPCT  \
# name                         ...
# Aruba                 NaN    ...           NaN       NaN       NaN       NaN
# Afghanistan    27,000,000    ...           0.0       0.0  0.000099  0.002000
# Angola         19,114,176    ...           0.0       0.0  0.075899  0.017899
# Anguilla              NaN    ...           NaN       NaN       NaN       NaN
# Åland Islands         NaN    ...           NaN       NaN       NaN       NaN
#
#                OTGENPCT  SUMPCT  2016_gdp_total  2016_gdp_capita  \
# name
# Aruba               NaN     NaN             NaN              NaN
# Afghanistan      0.0014  0.9986    1.946902e+10       561.778746
# Angola           0.0044  0.9956    8.963316e+10      3110.808183
# Anguilla            NaN     NaN             NaN              NaN
# Åland Islands       NaN     NaN             NaN              NaN
#
#                                                         gov_type  ISO_num_y
# name
# Aruba          parliamentary democracy (Legislature); part of...        533
# Afghanistan                        presidential Islamic republic        004
# Angola                                     presidential republic        024
# Anguilla       parliamentary democracy (House of Assembly); s...        660
# Åland Islands                                            unknown        248
#
# [5 rows x 51 columns]

# %% [markdown]
# ### Formatting religion column

# %% [markdown]
# As we can see, in the dataframe we still have the annoying religion columns. We would like to compress all the information of the religion in one single column.
#
# We are only interested in the main religions, so we set a treshold of 10% of adherents. To consider that a country has a certain religion, the percentage of adherents has to be superior to 10%. Obviously, one country can have more than one religion.
#
# Empty dictionary values in the religion column mean that we didn't have any data on the religion percentages.

# %%
def get_main_religions(df):
    """This function takes all religion columns and returns the dictionary needed to create the single religion column.
    The items of the dictionary are like the following {country: {religion1: percentage1, ... , religionN: percentageN}}"""
    treshold = 0.1
    religions_dict = dict()
    for country in data.index:
        religions = {}
        for religion in religion_cols:
            pct = data.loc[country, religion]
            if pct >= treshold:
                religions.update({religion: pct})
        religions_dict.update({country: religions})

    return religions_dict

# %%
# Renaming religion columns
new_names = {'CHGENPCT': 'Christianism', 'JDGENPCT': 'Judaism', 'ISGENPCT': 'Islam', 'BUGENPCT': 'Buddhism',
             'ZOGENPCT': 'Zoroastrian', 'HIGENPCT': 'Hindu', 'SIGENPCT': 'Sikh', 'SHGENPCT': 'Shinto', 
             'BAGENPCT': "Baha'i", 'TAGENPCT': 'Taoism', 'JAGENPCT': 'Jain', 'COGENPCT': 'Confucianism', 
             'SYGENPCT': 'Syncretic religions', 'ANGENPCT': 'Animist religions', 'NORELPCT': 'Non-religious', 
             'OTGENPCT': 'Other religions'}

religion_cols = new_names.values()
data.rename(columns=new_names, inplace=True)

# Adding the column to the dataframe
data['religion'] = get_main_religions(data).values()

# Selecting only useful columns
cols = ['area', 'ISO2', 'ISO3', 'languages', 'borders', 'latlng', 'language_codes',  'POP', 'religion', '2016_gdp_total', '2016_gdp_capita', 'gov_type']
data = data[cols]
data.head()
# Out:
#                     area ISO2 ISO3                languages  \
# name
# Aruba              180.0   AW  ABW      [Dutch, Papiamento]
# Afghanistan     652230.0   AF  AFG  [Dari, Pashto, Turkmen]
# Angola         1246700.0   AO  AGO             [Portuguese]
# Anguilla            91.0   AI  AIA                [English]
# Åland Islands     1580.0   AX  ALA                [Swedish]
#
#                                       borders                 latlng  \
# name
# Aruba                                      []   [12.5, -69.96666666]
# Afghanistan    [IRN, PAK, TKM, UZB, TJK, CHN]               [33, 65]
# Angola                   [COG, COD, ZMB, NAM]          [-12.5, 18.5]
# Anguilla                                   []  [18.25, -63.16666666]
# Åland Islands                              []      [60.116667, 19.9]
#
#                 language_codes         POP                  religion  \
# name
# Aruba               [nld, pap]         NaN                        {}
# Afghanistan    [prs, pus, tuk]  27,000,000         {'Islam': 0.9956}
# Angola                   [por]  19,114,176  {'Christianism': 0.8912}
# Anguilla                 [eng]         NaN                        {}
# Åland Islands            [swe]         NaN                        {}
#
#                2016_gdp_total  2016_gdp_capita  \
# name
# Aruba                     NaN              NaN
# Afghanistan      1.946902e+10       561.778746
# Angola           8.963316e+10      3110.808183
# Anguilla                  NaN              NaN
# Åland Islands             NaN              NaN
#
#                                                         gov_type
# name
# Aruba          parliamentary democracy (Legislature); part of...
# Afghanistan                        presidential Islamic republic
# Angola                                     presidential republic
# Anguilla       parliamentary democracy (House of Assembly); s...
# Åland Islands                                            unknown

# %% [markdown]
# ### Categorizing government type column
#
# The last step is to make the government type column categorical. As we can see in the cell below, the column has a certain common format for each class of government, but it's still not useful. It needs some cleaning.

# %%
data.gov_type.fillna('unknown', inplace=True)
data.gov_type
# Out:
# name
# Aruba                                   parliamentary democracy (Legislature); part of...
# Afghanistan                                                 presidential Islamic republic
# Angola                                                              presidential republic
# Anguilla                                parliamentary democracy (House of Assembly); s...
# Åland Islands                                                                     unknown
# Albania                                                            parliamentary republic
# Andorra                                 parliamentary democracy (since March 1993) tha...
# United Arab Emirates                                             federation of monarchies
# Argentina                                                           presidential republic
# Armenia                                                        semi-presidential republic
# American Samoa                          presidential democracy; a self-governing terri...
# Antarctica                                                                        unknown
# French Southern and Antarctic Lands                                               unknown
# Antigua and Barbuda                     parliamentary democracy (Parliament) under a c...
# Australia                               parliamentary democracy (Federal Parliament) u...
# Austria                                                    federal parliamentary republic
# Azerbaijan                                                          presidential republic
# Burundi                                                             presidential republic
# Belgium                                 federal parliamentary democracy under a consti...
# Benin                                                               presidential republic
# Burkina Faso                                                        presidential republic
# Bangladesh                                                         parliamentary republic
# Bulgaria                                                           parliamentary republic
# Bahrain                                                           constitutional monarchy
# Bahamas                                 parliamentary democracy (Parliament) under a c...
# Bosnia and Herzegovina                                             parliamentary republic
# Saint Barthélemy                                                                  unknown
# Belarus                                 presidential republic in name, although in fac...
# Belize                                  parliamentary democracy (National Assembly) un...
# Bermuda                                 parliamentary democracy (Parliament); self-gov...
#                                                               ...
# Tajikistan                                                          presidential republic
# Tokelau                                 parliamentary democratic dependency (General F...
# Turkmenistan                                  presidential republic; highly authoritarian
# Timor-Leste                                                    semi-presidential republic
# Tonga                                                             constitutional monarchy
# Trinidad and Tobago                                                parliamentary republic
# Tunisia                                                            parliamentary republic
# Turkey                                                             parliamentary republic
# Tuvalu                                  parliamentary democracy (House of Assembly) un...
# Taiwan                                                         semi-presidential republic
# Tanzania                                                            presidential republic
# Uganda                                                              presidential republic
# Ukraine                                                        semi-presidential republic
# United States Minor Outlying Islands                                              unknown
# Uruguay                                                             presidential republic
# United States                                             constitutional federal republic
# Uzbekistan                                    presidential republic; highly authoritarian
# Vatican City                            ecclesiastical elective monarchy; self describ...
# Saint Vincent and the Grenadines        parliamentary democracy (House of Assembly) un...
# Venezuela                                                   federal presidential republic
# British Virgin Islands                  parliamentary democracy (House of Assembly); s...
# United States Virgin Islands            presidential democracy; a self-governing terri...
# Vietnam                                                                   communist state
# Vanuatu                                                            parliamentary republic
# Wallis and Futuna                       parliamentary democracy (Territorial Assembly)...
# Samoa                                                              parliamentary republic
# Yemen                                                                       in transition
# South Africa                                                       parliamentary republic
# Zambia                                                              presidential republic
# Zimbabwe                                                       semi-presidential republic
# Name: gov_type, Length: 248, dtype: object

# %% [markdown]
# ### Methodology
# We are going to run a function to all the rows of the gov_type column that will return the most common sequences of words, so that we can then manually check which are the main type of government.
#
# The types of government considered where:
# - parliamentary democracy
# - parliamentary republic
# - presidential republic
# - semi-presidential republic
# - presidential democracy
# - absolute monarchy
# - federal republic
# - communist state
# - monarchy
# - others
#
# Missing data is under the category 'unknown'.

# %%
def phrases(string):
    """Splits the input string on whitespace and returns all possible substrings of any length"""
    words = string.split()
    result = []
    for number in range(len(words)):
        for start in range(len(words)-number):
             result.append(" ".join(words[start:start+number+1]))
    return result

# Example
phrases('Hi my name is Jacob')
# Out:
# ['Hi',
#  'my',
#  'name',
#  'is',
#  'Jacob',
#  'Hi my',
#  'my name',
#  'name is',
#  'is Jacob',
#  'Hi my name',
#  'my name is',
#  'name is Jacob',
#  'Hi my name is',
#  'my name is Jacob',
#  'Hi my name is Jacob']

# %%
all_strings = list(data.gov_type)

# Counts all ocurrences of a substring 
all_phrases = collections.Counter(phrase for subject in all_strings for phrase in phrases(subject))

# Printing the most common substrings and the number of occurences
ocurrences = [(phrase, count) for phrase, count in all_phrases.items() if count > 1]
ocurrences[:10]
# Out:
# [('parliamentary', 99),
#  ('democracy', 41),
#  ('part', 4),
#  ('of', 59),
#  ('the', 45),
#  ('Kingdom', 4),
#  ('Netherlands', 2),
#  ('parliamentary democracy', 40),
#  ('part of', 4),
#  ('of the', 28)]

# %% [markdown]
# When looking at the government types, we noticed that most of them had could be expressed in two or three words so we filtered down to the substrings of these kind, to make the manual checking simpler.

# %%
# Filtering down to sequences of 2 or 3 words
filtered_ocurrences = [ocurrences[i][0] for i in range(len(ocurrences)) if 2 <= len(ocurrences[i][0].split()) <= 3]
filtered_ocurrences[:10]
# Out:
# ['parliamentary democracy',
#  'part of',
#  'of the',
#  'the Kingdom',
#  'Kingdom of',
#  'the Netherlands',
#  'part of the',
#  'of the Kingdom',
#  'the Kingdom of',
#  'Kingdom of the']

# %%
# Manually changing some countries data
data.loc['Tokelau', 'gov_type'] = 'parliamentary democracy'
data.loc['Vatican City', 'gov_type'] = 'monarchy'
data.loc['Hong Kong', 'gov_type'] = 'presidential democracy'
data.loc['Macau', 'gov_type'] = 'presidential democracy'

# %%
# Types of government
governments = ['parliamentary democracy', 'parliamentary republic', 'presidential democracy', 'presidential republic', 
               'semi-presidential republic', 'absolute monarchy', 'federal republic', 'communist state', 
               'monarchy', 'unknown']

# %%
def categorize_government_types():
    for gov in governments:
        for country in data.index:
            if gov in data.loc[country, 'gov_type']:
                if (gov == 'presidential republic') & ('semi-presidential republic' in data.loc[country, 'gov_type']):
                    pass
                data.loc[country, 'gov_type'] = gov
    
categorize_government_types()

idx = [idx for idx, i in enumerate(data.gov_type) if i not in governments]
data.reset_index(inplace=True)
data.loc[idx, 'gov_type'] = 'other'
data.set_index('name', inplace=True)

# %%
data['Active tweeter users'] = 'TBD'

# %%
def replace_commas_in_integer(df):
    df.POP = df.POP.apply(str)
    df.POP = df.POP.apply(str.replace, args=(',', ''))
    df.POP = df.POP.apply(float)
    return df

def convert_to_numeric(df):
    for column in df.columns:
        try:
            df[column] = pd.to_numeric(df[column])
        except:
            pass
    return df

data = replace_commas_in_integer(data)
data = convert_to_numeric(data)

# %%
data.to_pickle('data.pickle')

# %%
data
# Out:
#                                              area ISO2 ISO3  \
# name
# Aruba                                      180.00   AW  ABW
# Afghanistan                             652230.00   AF  AFG
# Angola                                 1246700.00   AO  AGO
# Anguilla                                    91.00   AI  AIA
# Åland Islands                             1580.00   AX  ALA
# Albania                                  28748.00   AL  ALB
# Andorra                                    468.00   AD  AND
# United Arab Emirates                     83600.00   AE  ARE
# Argentina                              2780400.00   AR  ARG
# Armenia                                  29743.00   AM  ARM
# American Samoa                             199.00   AS  ASM
# Antarctica                            14000000.00   AQ  ATA
# French Southern and Antarctic Lands       7747.00   TF  ATF
# Antigua and Barbuda                        442.00   AG  ATG
# Australia                              7692024.00   AU  AUS
# Austria                                  83871.00   AT  AUT
# Azerbaijan                               86600.00   AZ  AZE
# Burundi                                  27834.00   BI  BDI
# Belgium                                  30528.00   BE  BEL
# Benin                                   112622.00   BJ  BEN
# Burkina Faso                            272967.00   BF  BFA
# Bangladesh                              147570.00   BD  BGD
# Bulgaria                                110879.00   BG  BGR
# Bahrain                                    765.00   BH  BHR
# Bahamas                                  13943.00   BS  BHS
# Bosnia and Herzegovina                   51209.00   BA  BIH
# Saint Barthélemy                            21.00   BL  BLM
# Belarus                                 207600.00   BY  BLR
# Belize                                   22966.00   BZ  BLZ
# Bermuda                                     54.00   BM  BMU
# ...                                           ...  ...  ...
# Tajikistan                              143100.00   TJ  TJK
# Tokelau                                     12.00   TK  TKL
# Turkmenistan                            488100.00   TM  TKM
# Timor-Leste                              14874.00   TL  TLS
# Tonga                                      747.00   TO  TON
# Trinidad and Tobago                       5130.00   TT  TTO
# Tunisia                                 163610.00   TN  TUN
# Turkey                                  783562.00   TR  TUR
# Tuvalu                                      26.00   TV  TUV
# Taiwan                                   36193.00   TW  TWN
# Tanzania                                945087.00   TZ  TZA
# Uganda                                  241550.00   UG  UGA
# Ukraine                                 603500.00   UA  UKR
# United States Minor Outlying Islands        34.20   UM  UMI
# Uruguay                                 181034.00   UY  URY
# United States                          9372610.00   US  USA
# Uzbekistan                              447400.00   UZ  UZB
# Vatican City                                 0.44   VA  VAT
# Saint Vincent and the Grenadines           389.00   VC  VCT
# Venezuela                               916445.00   VE  VEN
# British Virgin Islands                     151.00   VG  VGB
# United States Virgin Islands               347.00   VI  VIR
# Vietnam                                 331212.00   VN  VNM
# Vanuatu                                  12189.00   VU  VUT
# Wallis and Futuna                          142.00   WF  WLF
# Samoa                                     2842.00   WS  WSM
# Yemen                                   527968.00   YE  YEM
# South Africa                           1221037.00   ZA  ZAF
# Zambia                                  752612.00   ZM  ZMB
# Zimbabwe                                390757.00   ZW  ZWE
#
#                                                                               languages  \
# name
# Aruba                                                               [Dutch, Papiamento]
# Afghanistan                                                     [Dari, Pashto, Turkmen]
# Angola                                                                     [Portuguese]
# Anguilla                                                                      [English]
# Åland Islands                                                                 [Swedish]
# Albania                                                                      [Albanian]
# Andorra                                                                       [Catalan]
# United Arab Emirates                                                           [Arabic]
# Argentina                                                            [Guaraní, Spanish]
# Armenia                                                             [Armenian, Russian]
# American Samoa                                                        [English, Samoan]
# Antarctica                                                                           []
# French Southern and Antarctic Lands                                            [French]
# Antigua and Barbuda                                                           [English]
# Australia                                                                     [English]
# Austria                                                        [Austro-Bavarian German]
# Azerbaijan                                                       [Azerbaijani, Russian]
# Burundi                                                               [French, Kirundi]
# Belgium                                                         [German, French, Dutch]
# Benin                                                                          [French]
# Burkina Faso                                                                   [French]
# Bangladesh                                                                    [Bengali]
# Bulgaria                                                                    [Bulgarian]
# Bahrain                                                                        [Arabic]
# Bahamas                                                                       [English]
# Bosnia and Herzegovina                                     [Bosnian, Croatian, Serbian]
# Saint Barthélemy                                                               [French]
# Belarus                                                           [Belarusian, Russian]
# Belize                                              [Belizean Creole, English, Spanish]
# Bermuda                                                                       [English]
# ...                                                                                 ...
# Tajikistan                                                             [Russian, Tajik]
# Tokelau                                                    [English, Samoan, Tokelauan]
# Turkmenistan                                                         [Russian, Turkmen]
# Timor-Leste                                                         [Portuguese, Tetum]
# Tonga                                                                 [English, Tongan]
# Trinidad and Tobago                                                           [English]
# Tunisia                                                                        [Arabic]
# Turkey                                                                        [Turkish]
# Tuvalu                                                              [English, Tuvaluan]
# Taiwan                                                                        [Chinese]
# Tanzania                                                             [English, Swahili]
# Uganda                                                               [English, Swahili]
# Ukraine                                                                     [Ukrainian]
# United States Minor Outlying Islands                                          [English]
# Uruguay                                                                       [Spanish]
# United States                                                                 [English]
# Uzbekistan                                                             [Russian, Uzbek]
# Vatican City                                                           [Italian, Latin]
# Saint Vincent and the Grenadines                                              [English]
# Venezuela                                                                     [Spanish]
# British Virgin Islands                                                        [English]
# United States Virgin Islands                                                  [English]
# Vietnam                                                                    [Vietnamese]
# Vanuatu                                                      [Bislama, English, French]
# Wallis and Futuna                                                              [French]
# Samoa                                                                 [English, Samoan]
# Yemen                                                                          [Arabic]
# South Africa                          [Afrikaans, English, Southern Ndebele, Norther...
# Zambia                                                                        [English]
# Zimbabwe                              [Chibarwe, English, Kalanga, Khoisan, Ndau, No...
#
#                                                                        borders  \
# name
# Aruba                                                                       []
# Afghanistan                                     [IRN, PAK, TKM, UZB, TJK, CHN]
# Angola                                                    [COG, COD, ZMB, NAM]
# Anguilla                                                                    []
# Åland Islands                                                               []
# Albania                                                   [MNE, GRC, MKD, UNK]
# Andorra                                                             [FRA, ESP]
# United Arab Emirates                                                [OMN, SAU]
# Argentina                                            [BOL, BRA, CHL, PRY, URY]
# Armenia                                                   [AZE, GEO, IRN, TUR]
# American Samoa                                                              []
# Antarctica                                                                  []
# French Southern and Antarctic Lands                                         []
# Antigua and Barbuda                                                         []
# Australia                                                                   []
# Austria                               [CZE, DEU, HUN, ITA, LIE, SVK, SVN, CHE]
# Azerbaijan                                           [ARM, GEO, IRN, RUS, TUR]
# Burundi                                                        [COD, RWA, TZA]
# Belgium                                                   [FRA, DEU, LUX, NLD]
# Benin                                                     [BFA, NER, NGA, TGO]
# Burkina Faso                                    [BEN, CIV, GHA, MLI, NER, TGO]
# Bangladesh                                                          [MMR, IND]
# Bulgaria                                             [GRC, MKD, ROU, SRB, TUR]
# Bahrain                                                                     []
# Bahamas                                                                     []
# Bosnia and Herzegovina                                         [HRV, MNE, SRB]
# Saint Barthélemy                                                            []
# Belarus                                              [LVA, LTU, POL, RUS, UKR]
# Belize                                                              [GTM, MEX]
# Bermuda                                                                     []
# ...                                                                        ...
# Tajikistan                                                [AFG, CHN, KGZ, UZB]
# Tokelau                                                                     []
# Turkmenistan                                              [AFG, IRN, KAZ, UZB]
# Timor-Leste                                                              [IDN]
# Tonga                                                                       []
# Trinidad and Tobago                                                         []
# Tunisia                                                             [DZA, LBY]
# Turkey                                [ARM, AZE, BGR, GEO, GRC, IRN, IRQ, SYR]
# Tuvalu                                                                      []
# Taiwan                                                                      []
# Tanzania                              [BDI, COD, KEN, MWI, MOZ, RWA, UGA, ZMB]
# Uganda                                               [COD, KEN, RWA, SSD, TZA]
# Ukraine                                    [BLR, HUN, MDA, POL, ROU, RUS, SVK]
# United States Minor Outlying Islands                                        []
# Uruguay                                                             [ARG, BRA]
# United States                                                       [CAN, MEX]
# Uzbekistan                                           [AFG, KAZ, KGZ, TJK, TKM]
# Vatican City                                                             [ITA]
# Saint Vincent and the Grenadines                                            []
# Venezuela                                                      [BRA, COL, GUY]
# British Virgin Islands                                                      []
# United States Virgin Islands                                                []
# Vietnam                                                        [KHM, CHN, LAO]
# Vanuatu                                                                     []
# Wallis and Futuna                                                           []
# Samoa                                                                       []
# Yemen                                                               [OMN, SAU]
# South Africa                                    [BWA, LSO, MOZ, NAM, SWZ, ZWE]
# Zambia                                [AGO, BWA, COD, MWI, MOZ, NAM, TZA, ZWE]
# Zimbabwe                                                  [BWA, MOZ, ZAF, ZMB]
#
#                                                              latlng  \
# name
# Aruba                                          [12.5, -69.96666666]
# Afghanistan                                                [33, 65]
# Angola                                                [-12.5, 18.5]
# Anguilla                                      [18.25, -63.16666666]
# Åland Islands                                     [60.116667, 19.9]
# Albania                                                    [41, 20]
# Andorra                                                 [42.5, 1.5]
# United Arab Emirates                                       [24, 54]
# Argentina                                                [-34, -64]
# Armenia                                                    [40, 45]
# American Samoa                                 [-14.33333333, -170]
# Antarctica                                                 [-90, 0]
# French Southern and Antarctic Lands                [-49.25, 69.167]
# Antigua and Barbuda                                  [17.05, -61.8]
# Australia                                                [-27, 133]
# Austria                                  [47.33333333, 13.33333333]
# Azerbaijan                                             [40.5, 47.5]
# Burundi                                                  [-3.5, 30]
# Belgium                                            [50.83333333, 4]
# Benin                                                   [9.5, 2.25]
# Burkina Faso                                               [13, -2]
# Bangladesh                                                 [24, 90]
# Bulgaria                                                   [43, 25]
# Bahrain                                                 [26, 50.55]
# Bahamas                                                [24.25, -76]
# Bosnia and Herzegovina                                     [44, 18]
# Saint Barthélemy                               [18.5, -63.41666666]
# Belarus                                                    [53, 28]
# Belize                                              [17.25, -88.75]
# Bermuda                                       [32.33333333, -64.75]
# ...                                                             ...
# Tajikistan                                                 [39, 71]
# Tokelau                                                  [-9, -172]
# Turkmenistan                                               [40, 60]
# Timor-Leste                             [-8.83333333, 125.91666666]
# Tonga                                                   [-20, -175]
# Trinidad and Tobago                                       [11, -61]
# Tunisia                                                     [34, 9]
# Turkey                                                     [39, 35]
# Tuvalu                                                    [-8, 178]
# Taiwan                                                  [23.5, 121]
# Tanzania                                                   [-6, 35]
# Uganda                                                      [1, 32]
# Ukraine                                                    [49, 32]
# United States Minor Outlying Islands                             []
# Uruguay                                                  [-33, -56]
# United States                                             [38, -97]
# Uzbekistan                                                 [41, 64]
# Vatican City                                          [41.9, 12.45]
# Saint Vincent and the Grenadines                     [13.25, -61.2]
# Venezuela                                                  [8, -66]
# British Virgin Islands                       [18.431383, -64.62305]
# United States Virgin Islands                    [18.35, -64.933333]
# Vietnam                                 [16.16666666, 107.83333333]
# Vanuatu                                                  [-16, 167]
# Wallis and Futuna                                   [-13.3, -176.2]
# Samoa                                 [-13.58333333, -172.33333333]
# Yemen                                                      [15, 48]
# South Africa                                              [-29, 24]
# Zambia                                                    [-15, 30]
# Zimbabwe                                                  [-20, 30]
#
#                                                                          language_codes  \
# name
# Aruba                                                                        [nld, pap]
# Afghanistan                                                             [prs, pus, tuk]
# Angola                                                                            [por]
# Anguilla                                                                          [eng]
# Åland Islands                                                                     [swe]
# Albania                                                                           [sqi]
# Andorra                                                                           [cat]
# United Arab Emirates                                                              [ara]
# Argentina                                                                    [grn, spa]
# Armenia                                                                      [hye, rus]
# American Samoa                                                               [eng, smo]
# Antarctica                                                                    [unknown]
# French Southern and Antarctic Lands                                               [fra]
# Antigua and Barbuda                                                               [eng]
# Australia                                                                         [eng]
# Austria                                                                           [bar]
# Azerbaijan                                                                   [aze, rus]
# Burundi                                                                      [fra, run]
# Belgium                                                                 [deu, fra, nld]
# Benin                                                                             [fra]
# Burkina Faso                                                                      [fra]
# Bangladesh                                                                        [ben]
# Bulgaria                                                                          [bul]
# Bahrain                                                                           [ara]
# Bahamas                                                                           [eng]
# Bosnia and Herzegovina                                                  [bos, hrv, srp]
# Saint Barthélemy                                                                  [fra]
# Belarus                                                                      [bel, rus]
# Belize                                                                  [bjz, eng, spa]
# Bermuda                                                                           [eng]
# ...                                                                                 ...
# Tajikistan                                                                   [rus, tgk]
# Tokelau                                                                 [eng, smo, tkl]
# Turkmenistan                                                                 [rus, tuk]
# Timor-Leste                                                                  [por, tet]
# Tonga                                                                        [eng, ton]
# Trinidad and Tobago                                                               [eng]
# Tunisia                                                                           [ara]
# Turkey                                                                            [tur]
# Tuvalu                                                                       [eng, tvl]
# Taiwan                                                                            [zho]
# Tanzania                                                                     [eng, swa]
# Uganda                                                                       [eng, swa]
# Ukraine                                                                           [ukr]
# United States Minor Outlying Islands                                              [eng]
# Uruguay                                                                           [spa]
# United States                                                                     [eng]
# Uzbekistan                                                                   [rus, uzb]
# Vatican City                                                                 [ita, lat]
# Saint Vincent and the Grenadines                                                  [eng]
# Venezuela                                                                         [spa]
# British Virgin Islands                                                            [eng]
# United States Virgin Islands                                                      [eng]
# Vietnam                                                                           [vie]
# Vanuatu                                                                 [bis, eng, fra]
# Wallis and Futuna                                                                 [fra]
# Samoa                                                                        [eng, smo]
# Yemen                                                                             [ara]
# South Africa                          [afr, eng, nbl, nso, sot, ssw, tsn, tso, ven, ...
# Zambia                                                                            [eng]
# Zimbabwe                              [bwg, eng, kck, khi, ndc, nde, nya, sna, sot, ...
#
#                                               POP  \
# name
# Aruba                                         NaN
# Afghanistan                            27000000.0
# Angola                                 19114176.0
# Anguilla                                      NaN
# Åland Islands                                 NaN
# Albania                                 3195525.0
# Andorra                                   85500.0
# United Arab Emirates                    6236650.0
# Argentina                              40399992.0
# Armenia                                 3245781.0
# American Samoa                                NaN
# Antarctica                                    NaN
# French Southern and Antarctic Lands           NaN
# Antigua and Barbuda                           NaN
# Australia                              21400000.0
# Austria                                 8389771.0
# Azerbaijan                              9047615.0
# Burundi                                 8595166.0
# Belgium                                10876395.0
# Benin                                   8785996.0
# Burkina Faso                           15583968.0
# Bangladesh                            147290688.0
# Bulgaria                                7543557.0
# Bahrain                                 1234571.0
# Bahamas                                  313312.0
# Bosnia and Herzegovina                  3823795.0
# Saint Barthélemy                              NaN
# Belarus                                 9490500.0
# Belize                                   304106.0
# Bermuda                                       NaN
# ...                                           ...
# Tajikistan                              7436448.0
# Tokelau                                       NaN
# Turkmenistan                            5616004.0
# Timor-Leste                             1127779.0
# Tonga                                    104817.0
# Trinidad and Tobago                     1305000.0
# Tunisia                                10548997.0
# Turkey                                 76787632.0
# Tuvalu                                    10067.0
# Taiwan                                 22770000.0
# Tanzania                               43070004.0
# Uganda                                 31118996.0
# Ukraine                                46005476.0
# United States Minor Outlying Islands          NaN
# Uruguay                                 3356679.0
# United States                         312750000.0
# Uzbekistan                             28160570.0
# Vatican City                                  NaN
# Saint Vincent and the Grenadines         104000.0
# Venezuela                              28834000.0
# British Virgin Islands                        NaN
# United States Virgin Islands                  NaN
# Vietnam                                       NaN
# Vanuatu                                  241400.0
# Wallis and Futuna                             NaN
# Samoa                                    188861.0
# Yemen                                  23605382.0
# South Africa                           50022088.0
# Zambia                                 13039656.0
# Zimbabwe                               12165294.0
#
#                                                                                religion  \
# name
# Aruba                                                                                {}
# Afghanistan                                                           {'Islam': 0.9956}
# Angola                                                         {'Christianism': 0.8912}
# Anguilla                                                                             {}
# Åland Islands                                                                        {}
# Albania                               {'Christianism': 0.2144, 'Islam': 0.63, 'Non-r...
# Andorra                                                         {'Christianism': 0.907}
# United Arab Emirates                                 {'Islam': 0.6748, 'Hindu': 0.2225}
# Argentina                               {'Christianism': 0.8515, 'Non-religious': 0.12}
# Armenia                                                         {'Christianism': 0.951}
# American Samoa                                                                       {}
# Antarctica                                                                           {}
# French Southern and Antarctic Lands                                                  {}
# Antigua and Barbuda                                                                  {}
# Australia                             {'Christianism': 0.6145, 'Non-religious': 0.3101}
# Austria                                 {'Christianism': 0.73, 'Non-religious': 0.1542}
# Azerbaijan                                                              {'Islam': 0.95}
# Burundi                                                         {'Christianism': 0.889}
# Belgium                                 {'Christianism': 0.692, 'Non-religious': 0.192}
# Benin                                 {'Christianism': 0.4, 'Islam': 0.2647, 'Animis...
# Burkina Faso                          {'Christianism': 0.2935, 'Islam': 0.579, 'Anim...
# Bangladesh                                                             {'Islam': 0.897}
# Bulgaria                              {'Christianism': 0.8227, 'Islam': 0.128898765432}
# Bahrain                                                                {'Islam': 0.896}
# Bahamas                                                         {'Christianism': 0.966}
# Bosnia and Herzegovina                            {'Christianism': 0.52, 'Islam': 0.45}
# Saint Barthélemy                                                                     {}
# Belarus                                {'Christianism': 0.5684, 'Non-religious': 0.411}
# Belize                                {'Christianism': 0.7365, 'Non-religious': 0.15...
# Bermuda                                                                              {}
# ...                                                                                 ...
# Tajikistan                                                               {'Islam': 0.9}
# Tokelau                                                                              {}
# Turkmenistan                                                            {'Islam': 0.89}
# Timor-Leste                                                      {'Christianism': 0.98}
# Tonga                                                          {'Christianism': 0.9421}
# Trinidad and Tobago                   {'Christianism': 0.5588, 'Hindu': 0.184, 'Non-...
# Tunisia                                                                 {'Islam': 0.99}
# Turkey                                                                {'Islam': 0.9858}
# Tuvalu                                                         {'Christianism': 0.9699}
# Taiwan                                {'Buddhism': 0.2508, 'Taoism': 0.2078, 'Syncre...
# Tanzania                              {'Christianism': 0.4777, 'Islam': 0.36, 'Animi...
# Uganda                                           {'Christianism': 0.833, 'Islam': 0.12}
# Ukraine                                {'Christianism': 0.852, 'Non-religious': 0.1348}
# United States Minor Outlying Islands                                                 {}
# Uruguay                                {'Christianism': 0.8183, 'Non-religious': 0.172}
# United States                           {'Christianism': 0.7454, 'Non-religious': 0.19}
# Uzbekistan                                                              {'Islam': 0.93}
# Vatican City                                                                         {}
# Saint Vincent and the Grenadines                                {'Christianism': 0.899}
# Venezuela                                                        {'Christianism': 0.95}
# British Virgin Islands                                                               {}
# United States Virgin Islands                                                         {}
# Vietnam                                                                              {}
# Vanuatu                                                          {'Christianism': 0.85}
# Wallis and Futuna                                                                    {}
# Samoa                                                          {'Christianism': 0.9538}
# Yemen                                                                   {'Islam': 0.99}
# South Africa                                                   {'Christianism': 0.8094}
# Zambia                                {'Christianism': 0.87, 'Animist religions': 0....
# Zimbabwe                              {'Christianism': 0.8188, 'Animist religions': ...
#
#                                       2016_gdp_total  2016_gdp_capita  \
# name
# Aruba                                            NaN              NaN
# Afghanistan                             1.946902e+10       561.778746
# Angola                                  8.963316e+10      3110.808183
# Anguilla                                         NaN              NaN
# Åland Islands                                    NaN              NaN
# Albania                                 1.192689e+10      4146.896250
# Andorra                                          NaN              NaN
# United Arab Emirates                    3.487433e+11     37622.207458
# Argentina                               5.458662e+11     12449.216852
# Armenia                                 1.054733e+10      3606.152057
# American Samoa                                   NaN              NaN
# Antarctica                                       NaN              NaN
# French Southern and Antarctic Lands              NaN              NaN
# Antigua and Barbuda                     1.449160e+09     14353.378814
# Australia                               1.204616e+12     49927.819509
# Austria                                 3.864278e+11     44176.515216
# Azerbaijan                              3.784772e+10      3876.936433
# Burundi                                 3.007029e+09       285.727442
# Belgium                                 4.663657e+11     41096.157302
# Benin                                   8.583031e+09       789.440411
# Burkina Faso                            1.211516e+10       649.730484
# Bangladesh                              2.214153e+11      1358.779752
# Bulgaria                                5.239516e+10      7350.795801
# Bahrain                                 3.185851e+10     22354.167071
# Bahamas                                 9.047000e+09     23124.386553
# Bosnia and Herzegovina                  1.655970e+10      4708.718261
# Saint Barthélemy                                 NaN              NaN
# Belarus                                 4.743344e+10      4989.254611
# Belize                                  1.765256e+09      4810.565902
# Bermuda                                          NaN              NaN
# ...                                              ...              ...
# Tajikistan                              6.951657e+09       795.843864
# Tokelau                                          NaN              NaN
# Turkmenistan                            3.617989e+10      6389.334143
# Timor-Leste                                      NaN              NaN
# Tonga                                   3.951596e+08      3688.874636
# Trinidad and Tobago                     2.098916e+10     15377.098806
# Tunisia                                 4.206255e+10      3688.646375
# Turkey                                  8.577490e+11     10787.609339
# Tuvalu                                  3.421888e+07      3083.615251
# Taiwan                                           NaN              NaN
# Tanzania                                4.743104e+10       879.193814
# Uganda                                  2.552791e+10       615.308803
# Ukraine                                 9.327048e+10      2185.728031
# United States Minor Outlying Islands             NaN              NaN
# Uruguay                                 5.241972e+10     15220.566025
# United States                           1.856910e+13     57466.787113
# Uzbekistan                              6.722034e+10      2110.647872
# Vatican City                                     NaN              NaN
# Saint Vincent and the Grenadines        7.707966e+08      7030.057145
# Venezuela                                        NaN              NaN
# British Virgin Islands                           NaN              NaN
# United States Virgin Islands                     NaN              NaN
# Vietnam                                 2.026159e+11      2185.690282
# Vanuatu                                 7.735029e+08      2860.566475
# Wallis and Futuna                                NaN              NaN
# Samoa                                   7.859169e+08      4027.761370
# Yemen                                   2.731761e+10       990.334774
# South Africa                            2.948406e+11      5273.593880
# Zambia                                  1.955109e+10      1178.387905
# Zimbabwe                                1.628921e+10      1008.597331
#
#                                                      gov_type  \
# name
# Aruba                                 parliamentary democracy
# Afghanistan                                             other
# Angola                                  presidential republic
# Anguilla                              parliamentary democracy
# Åland Islands                                         unknown
# Albania                                parliamentary republic
# Andorra                               parliamentary democracy
# United Arab Emirates                                    other
# Argentina                               presidential republic
# Armenia                                 presidential republic
# American Samoa                         presidential democracy
# Antarctica                                            unknown
# French Southern and Antarctic Lands                   unknown
# Antigua and Barbuda                   parliamentary democracy
# Australia                             parliamentary democracy
# Austria                                parliamentary republic
# Azerbaijan                              presidential republic
# Burundi                                 presidential republic
# Belgium                               parliamentary democracy
# Benin                                   presidential republic
# Burkina Faso                            presidential republic
# Bangladesh                             parliamentary republic
# Bulgaria                               parliamentary republic
# Bahrain                                              monarchy
# Bahamas                               parliamentary democracy
# Bosnia and Herzegovina                 parliamentary republic
# Saint Barthélemy                                      unknown
# Belarus                                 presidential republic
# Belize                                parliamentary democracy
# Bermuda                               parliamentary democracy
# ...                                                       ...
# Tajikistan                              presidential republic
# Tokelau                               parliamentary democracy
# Turkmenistan                            presidential republic
# Timor-Leste                             presidential republic
# Tonga                                                monarchy
# Trinidad and Tobago                    parliamentary republic
# Tunisia                                parliamentary republic
# Turkey                                 parliamentary republic
# Tuvalu                                parliamentary democracy
# Taiwan                                  presidential republic
# Tanzania                                presidential republic
# Uganda                                  presidential republic
# Ukraine                                 presidential republic
# United States Minor Outlying Islands                  unknown
# Uruguay                                 presidential republic
# United States                                federal republic
# Uzbekistan                              presidential republic
# Vatican City                                         monarchy
# Saint Vincent and the Grenadines      parliamentary democracy
# Venezuela                               presidential republic
# British Virgin Islands                parliamentary democracy
# United States Virgin Islands           presidential democracy
# Vietnam                                       communist state
# Vanuatu                                parliamentary republic
# Wallis and Futuna                     parliamentary democracy
# Samoa                                  parliamentary republic
# Yemen                                                   other
# South Africa                           parliamentary republic
# Zambia                                  presidential republic
# Zimbabwe                                presidential republic
#
#                                      Active tweeter users
# name
# Aruba                                                 TBD
# Afghanistan                                           TBD
# Angola                                                TBD
# Anguilla                                              TBD
# Åland Islands                                         TBD
# Albania                                               TBD
# Andorra                                               TBD
# United Arab Emirates                                  TBD
# Argentina                                             TBD
# Armenia                                               TBD
# American Samoa                                        TBD
# Antarctica                                            TBD
# French Southern and Antarctic Lands                   TBD
# Antigua and Barbuda                                   TBD
# Australia                                             TBD
# Austria                                               TBD
# Azerbaijan                                            TBD
# Burundi                                               TBD
# Belgium                                               TBD
# Benin                                                 TBD
# Burkina Faso                                          TBD
# Bangladesh                                            TBD
# Bulgaria                                              TBD
# Bahrain                                               TBD
# Bahamas                                               TBD
# Bosnia and Herzegovina                                TBD
# Saint Barthélemy                                      TBD
# Belarus                                               TBD
# Belize                                                TBD
# Bermuda                                               TBD
# ...                                                   ...
# Tajikistan                                            TBD
# Tokelau                                               TBD
# Turkmenistan                                          TBD
# Timor-Leste                                           TBD
# Tonga                                                 TBD
# Trinidad and Tobago                                   TBD
# Tunisia                                               TBD
# Turkey                                                TBD
# Tuvalu                                                TBD
# Taiwan                                                TBD
# Tanzania                                              TBD
# Uganda                                                TBD
# Ukraine                                               TBD
# United States Minor Outlying Islands                  TBD
# Uruguay                                               TBD
# United States                                         TBD
# Uzbekistan                                            TBD
# Vatican City                                          TBD
# Saint Vincent and the Grenadines                      TBD
# Venezuela                                             TBD
# British Virgin Islands                                TBD
# United States Virgin Islands                          TBD
# Vietnam                                               TBD
# Vanuatu                                               TBD
# Wallis and Futuna                                     TBD
# Samoa                                                 TBD
# Yemen                                                 TBD
# South Africa                                          TBD
# Zambia                                                TBD
# Zimbabwe                                              TBD
#
# [248 rows x 13 columns]
